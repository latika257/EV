# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading files

# %%
car=pd.read_excel("3_ev_market_india_dataset.xlsx")
car.head()
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla  Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                      ID.3 Pure      10.0           160
# 2    Polestar                              2       4.7           210
# 3         BMW                            iX3       6.8           180
# 4       Honda                              e       9.5           145
#
#    Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161             940         Yes        AWD
# 1       270              167             250          No        RWD
# 2       400              181             620         Yes        AWD
# 3       360              206             560         Yes        RWD
# 4       170              168             190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
year_sale=pd.read_excel("Ev Sales.xlsx")
year_sale.head()
# Out:
#         YEAR  2 W   3 W  4 W  BUS  TOTAL
# 0 2017-04-01   96  4748  198    0   5042
# 1 2017-05-01   91  6720  215    2   7028
# 2 2017-06-01  137  7178  149    1   7465
# 3 2017-07-01  116  8775  120    0   9011
# 4 2017-08-01   99  8905  137    0   9141

# %%
charge=pd.read_excel("ev charging.xlsx")
charge.head()
# Out:
#         uid                    name             vendor_name  \
# 0  STATIC12  GensolCharge Pvt. Ltd.  GensolCharge Pvt. Ltd.
# 1  STATIC14                    REIL                    REIL
# 2  STATIC15                    REIL                    REIL
# 3  STATIC16                    REIL                    REIL
# 4  STATIC17                BluSmart                BluSmart
#
#                                       address   latitude  longitude   city  \
# 0             NDSE Grid, BRPL South Extension  28.568238  77.219666  Delhi
# 1                       Scada office kalka ji  28.541995  77.260583  Delhi
# 2                   Ashram Chowk Mathura Road  28.571189  77.259806  Delhi
# 3                  Nizamuddin Railway station  28.588991  77.253240  Delhi
# 4  BSES Bhawan, Nehru Place, New Delhi 110048  28.549427  77.254636  Delhi
#
#   country      open     close  ... postal_code           zone   0 available  \
# ...

# %%
group=pd.read_csv("maleorfemale.csv")
group.head()
# Out:
#         STATES / UTs   \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2               Assam
# 3               Bihar
# 4        Chhattisgarh
#
#    Professional - Authorised to drive public Service Vehicles - Male  \
# 0                                            43897.0
# 1                                             1979.0
# 2                                             1321.0
# 3                                            13567.0
# 4                                             1485.0
#
#    Professional - Authorised to drive public Service Vehicles - Female  \
# 0                                              286.0
# 1                                                NaN
# 2                                               11.0
# 3                                                5.0
# 4                                              367.0
#
#    Professional - Authorised to drive public Service Vehicles - Total  \
# 0                                            44183.0
# ...

# %%
regi=pd.read_csv("ev regis.csv")
regi.head()
# Out:
#   Sl. No.             Category     2022     2023  % Growth
# 0       1           2 Wheelers   631464   859376     36.09
# 1       2           3 Wheelers   352710   582793     65.23
# 2       3  Commercial Vehicles     2649     5673    114.16
# 3       4   Passenger Vehicles    38240    82105    114.71
# 4   Total                Total  1025063  1529947     49.25

# %% [markdown]
# # analyse the data

# %%
print("Car Data Shape",car.shape)
print("Info of data")
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
print(car.info())
print(car.describe())
print("-----------------------------------------------------------------------------------------------------------------")
print("charge station",charge.shape)
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
print(charge.info())
print(charge.describe())
print("-----------------------------------------------------------------------------------------------------------------")
print("Year wise sales",year_sale.shape)
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
print(year_sale.info())
print(year_sale.describe())
print("-----------------------------------------------------------------------------------------------------------------")
print("Group of cars male or female",group.shape)
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
print(group.info())
print(group.describe())
print("-----------------------------------------------------------------------------------------------------------------")
print("registration of cars",regi.shape)
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
print(regi.info())
print(regi.describe())
# Out:
# Car Data Shape (103, 14)
# Info of data
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    int64
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 11.4+ KB
# ...

# %%
print("Car Data Shape",car.shape)
print("Info of data")
# Out:
# Car Data Shape (103, 14)
# Info of data

# %%
print(car.info())
print(car.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    int64
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 11.4+ KB
# None
# ...

# %%
print("charge station",charge.shape)
# Out:
# charge station (2705, 25)

# %%
print(charge.info())
print(charge.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2705 entries, 0 to 2704
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   uid              2705 non-null   object
#  1   name             2705 non-null   object
#  2   vendor_name      2705 non-null   object
#  3   address          2705 non-null   object
#  4   latitude         2705 non-null   float64
#  5   longitude        2705 non-null   float64
#  6   city             2705 non-null   object
#  7   country          2705 non-null   object
#  8   open             2705 non-null   object
#  9   close            2705 non-null   object
#  10  logo_url         2238 non-null   object
#  11  staff            2705 non-null   object
#  12  payment_modes    2705 non-null   object
#  13  contact_numbers  2705 non-null   object
#  14  station_type     2705 non-null   object
#  15  postal_code      2705 non-null   int64
# ...

# %%
print("Year wise sales",year_sale.shape)
# Out:
# Year wise sales (74, 6)

# %%
print("Group of cars male or female",group.shape)
# Out:
# Group of cars male or female (37, 20)

# %%
print(group.info())
print(group.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 20 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   STATES / UTs                                                         37 non-null     object
#  1   Professional - Authorised to drive public Service Vehicles - Male    34 non-null     float64
#  2   Professional - Authorised to drive public Service Vehicles - Female  29 non-null     float64
#  3   Professional - Authorised to drive public Service Vehicles - Total   35 non-null     float64
#  4   Professional - Others - Male                                         32 non-null     float64
#  5   Professional - Others - Female                                       29 non-null     float64
# ...

# %%
print(year_sale.info())
print(year_sale.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YEAR    74 non-null     datetime64[ns]
#  1   2 W     74 non-null     int64
#  2   3 W     74 non-null     int64
#  3   4 W     74 non-null     int64
#  4   BUS     74 non-null     int64
#  5   TOTAL   74 non-null     int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 3.6 KB
# None
#                                 YEAR            2 W           3 W  \
# count                             74      74.000000     74.000000
# mean   2020-04-16 04:12:58.378378496   16938.729730  14851.351351
# min              2017-04-01 00:00:00      85.000000    668.000000
# 25%              2018-10-08 18:00:00    1304.250000   7782.250000
# 50%              2020-04-16 00:00:00    3014.500000  10619.500000
# 75%              2021-10-24 06:00:00   23599.000000  18641.750000
# ...

# %%
print("registration of cars",regi.shape)
# Out:
# registration of cars (5, 5)

# %%
print(regi.info())
print(regi.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sl. No.   5 non-null      object
#  1   Category  5 non-null      object
#  2   2022      5 non-null      int64
#  3   2023      5 non-null      int64
#  4   % Growth  5 non-null      float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 332.0+ bytes
# None
#                2022          2023    % Growth
# count  5.000000e+00  5.000000e+00    5.000000
# mean   4.100252e+05  6.119788e+05   75.888000
# std    4.285940e+05  6.231163e+05   36.670664
# min    2.649000e+03  5.673000e+03   36.090000
# 25%    3.824000e+04  8.210500e+04   49.250000
# 50%    3.527100e+05  5.827930e+05   65.230000
# 75%    6.314640e+05  8.593760e+05  114.160000
# max    1.025063e+06  1.529947e+06  114.710000

# %%
charge.head(5)
# Out:
#         uid                    name             vendor_name  \
# 0  STATIC12  GensolCharge Pvt. Ltd.  GensolCharge Pvt. Ltd.
# 1  STATIC14                    REIL                    REIL
# 2  STATIC15                    REIL                    REIL
# 3  STATIC16                    REIL                    REIL
# 4  STATIC17                BluSmart                BluSmart
#
#                                       address   latitude  longitude   city  \
# 0             NDSE Grid, BRPL South Extension  28.568238  77.219666  Delhi
# 1                       Scada office kalka ji  28.541995  77.260583  Delhi
# 2                   Ashram Chowk Mathura Road  28.571189  77.259806  Delhi
# 3                  Nizamuddin Railway station  28.588991  77.253240  Delhi
# 4  BSES Bhawan, Nehru Place, New Delhi 110048  28.549427  77.254636  Delhi
#
#   country      open     close  ... postal_code           zone   0 available  \
# ...

# %%
charge.columns
# Out:
# Index([            'uid',            'name',     'vendor_name',
#                'address',        'latitude',       'longitude',
#                   'city',         'country',            'open',
#                  'close',        'logo_url',           'staff',
#          'payment_modes', 'contact_numbers',    'station_type',
#            'postal_code',            'zone',                 0,
#              'available',        'capacity',   'cost_per_unit',
#             'power_type',           'total',            'type',
#           'vehicle_type'],
#       dtype='object')

# %%
car.head()
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla  Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                      ID.3 Pure      10.0           160
# 2    Polestar                              2       4.7           210
# 3         BMW                            iX3       6.8           180
# 4       Honda                              e       9.5           145
#
#    Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161             940         Yes        AWD
# 1       270              167             250          No        RWD
# 2       400              181             620         Yes        AWD
# 3       360              206             560         Yes        RWD
# 4       170              168             190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
charging_station = pd.read_excel('2_ev_charging_station_dataset.xlsx',)

# %%
charging_station.head()
# Out:
#   The number of electric vehicles currently being used on the roads of India, State wise as on\n\n14-07-2022  \
# 0                                            Sr. No.
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#                  Unnamed: 1              Unnamed: 2  \
# 0                State Name  Total Electric Vehicle
# 1  Andaman & Nicobar Island                     162
# 2         Arunachal Pradesh                      20
# 3                     Assam                   64766
# 4                     Bihar                   83335
#
#                    Unnamed: 3 Unnamed: 4
# 0  Total Non-Electric Vehicle      Total
# 1                      146945     147107
# 2                      252965     252985
# 3                     4677053    4741819
# 4                    10407078   10490413

# %% [markdown]
# ### Cleaning the data

# %%
charging_station.columns = charging_station.iloc[0]
charging_station = charging_station[1:]

# %%
charging_station.head()
# Out:
# 0 Sr. No.                State Name Total Electric Vehicle  \
# 1       1  Andaman & Nicobar Island                    162
# 2       2         Arunachal Pradesh                     20
# 3       3                     Assam                  64766
# 4       4                     Bihar                  83335
# 5       5                Chandigarh                   2812
#
# 0 Total Non-Electric Vehicle     Total
# 1                     146945    147107
# 2                     252965    252985
# 3                    4677053   4741819
# 4                   10407078  10490413
# 5                     746881    749693

# %%
charge.city.value_counts()
# Out:
# city
# New Delhi             1743
# Delhi                  704
# Nagpur                  98
# Chennai                 48
# Kolkata                 25
# Ahmedabad               12
# Raipur                   8
# Thiruvananthapuram       8
# Panaji                   6
# Kottayam                 6
# Kochi                    4
# Dehradun                 4
# Thrissur                 3
# Alappuzha                3
# Dhanbad                  3
# Kannur                   3
# Kozhikode                3
# Hardwar                  3
# Malappuram               3
# Mapusa                   3
# Kasaragod                3
# Palakkad                 3
# Kollam                   3
# Dwarka                   3
# Gurgaon                  2
# Bengaluru                1
# Name: count, dtype: int64

# %%
charge = pd.read_excel('2_ev_charging_station_dataset.xlsx',sheet_name='Table 4', header=1)
charge
# Out:
#              State/UT  EV Charging Facility
# 0      Andhra Pradesh                    65
# 1   Arunachal Pradesh                     4
# 2               Assam                    19
# 3               Bihar                    26
# 4          Chandigarh                     4
# 5        Chhattisgarh                    51
# 6               Delhi                    66
# 7                 Goa                    17
# 8             Gujarat                    87
# 9             Haryana                   114
# 10   Himachal Pradesh                    13
# 11          Jharkhand                    22
# 12                J&K                     3
# 13          Karnataka                   100
# 14             Kerala                    39
# 15                Leh                     2
# 16     Madhya Pradesh                   167
# 17         Maharastra                    88
# 18            Manipur                     1
# 19          Meghalaya                     3
# ...

# %%
group.head()
# Out:
#         STATES / UTs   \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2               Assam
# 3               Bihar
# 4        Chhattisgarh
#
#    Professional - Authorised to drive public Service Vehicles - Male  \
# 0                                            43897.0
# 1                                             1979.0
# 2                                             1321.0
# 3                                            13567.0
# 4                                             1485.0
#
#    Professional - Authorised to drive public Service Vehicles - Female  \
# 0                                              286.0
# 1                                                NaN
# 2                                               11.0
# 3                                                5.0
# 4                                              367.0
#
#    Professional - Authorised to drive public Service Vehicles - Total  \
# 0                                            44183.0
# ...

# %%
category = group[['State_UT','Total - Male','Total - Female']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 category = group[['State_UT','Total - Male','Total - Female']]
#
# File C:\Intel\gp\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\Intel\gp\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
# ...

# %%
group.rename(columns = {'STATES / UTs ':'State_UT'},inplace = True)
group.head()
# Out:
#              State_UT  \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2               Assam
# 3               Bihar
# 4        Chhattisgarh
#
#    Professional - Authorised to drive public Service Vehicles - Male  \
# 0                                            43897.0
# 1                                             1979.0
# 2                                             1321.0
# 3                                            13567.0
# 4                                             1485.0
#
#    Professional - Authorised to drive public Service Vehicles - Female  \
# 0                                              286.0
# 1                                                NaN
# 2                                               11.0
# 3                                                5.0
# 4                                              367.0
#
#    Professional - Authorised to drive public Service Vehicles - Total  \
# 0                                            44183.0
# ...

# %%
category = group[['State_UT','Total - Male','Total - Female']]

# %%
category
# Out:
#                        State_UT  Total - Male  Total - Female
# 0               Andhra Pradesh       700840.0         49939.0
# 1            Arunachal Pradesh        24810.0          4481.0
# 2                         Assam      253408.0         18171.0
# 3                         Bihar      884196.0         31427.0
# 4                  Chhattisgarh      642757.0         81252.0
# 5                           Goa       35555.0         17629.0
# 6                       Gujarat      728119.0         99102.0
# 7                      Haryana       282891.0         51525.0
# 8             Himachal Pradesh       191214.0         18197.0
# 9             Jammu and Kashmir       75199.0         18363.0
# 10                    Jharkhand      251438.0         22605.0
# 11                   Karnataka      1446334.0        193981.0
# 12                       Kerala      714139.0        295886.0
# 13               Madhya Pradesh      678039.0          2186.0
# ...

# %%
category.rename(columns = {'State_UT':'State_UTs','Total - Male':'Male','Total - Female':'Female'},inplace = True)
category.head()
# Out:
# C:\Users\latik\AppData\Local\Temp\ipykernel_3240\431988413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   category.rename(columns = {'State_UT':'State_UTs','Total - Male':'Male','Total - Female':'Female'},inplace = True)
#             State_UTs      Male   Female
# 0     Andhra Pradesh   700840.0  49939.0
# 1  Arunachal Pradesh    24810.0   4481.0
# 2               Assam  253408.0  18171.0
# 3               Bihar  884196.0  31427.0
# 4        Chhattisgarh  642757.0  81252.0

# %%
year_sale.head()
# Out:
#         YEAR  2 W   3 W  4 W  BUS  TOTAL
# 0 2017-04-01   96  4748  198    0   5042
# 1 2017-05-01   91  6720  215    2   7028
# 2 2017-06-01  137  7178  149    1   7465
# 3 2017-07-01  116  8775  120    0   9011
# 4 2017-08-01   99  8905  137    0   9141

# %%
year_sale['year'] = year_sale['YEAR'].apply(lambda x :x.year)

# %%
year_sale.head()
# Out:
#         YEAR  2 W   3 W  4 W  BUS  TOTAL  year
# 0 2017-04-01   96  4748  198    0   5042  2017
# 1 2017-05-01   91  6720  215    2   7028  2017
# 2 2017-06-01  137  7178  149    1   7465  2017
# 3 2017-07-01  116  8775  120    0   9011  2017
# 4 2017-08-01   99  8905  137    0   9141  2017

# %%
year_sale.groupby(['YEAR'])[['2 W','3 W','4 W','BUS','TOTAL','year']].sum()
# Out:
#                2 W    3 W   4 W  BUS   TOTAL  year
# YEAR
# 2017-04-01      96   4748   198    0    5042  2017
# 2017-05-01      91   6720   215    2    7028  2017
# 2017-06-01     137   7178   149    1    7465  2017
# 2017-07-01     116   8775   120    0    9011  2017
# 2017-08-01      99   8905   137    0    9141  2017
# ...            ...    ...   ...  ...     ...   ...
# 2023-01-01   64649  34308  3490   98  102545  2023
# 2023-02-01   66033  35995  4850   99  106977  2023
# 2023-03-01   86194  45225  8852   89  140360  2023
# 2023-04-01   66755  38016  6193   84  111048  2023
# 2023-05-01  105154  44615  7736  283  157788  2023
#
# [74 rows x 6 columns]

# %%
year_sale = year_sale.groupby(['YEAR'])[['2 W','3 W','4 W','BUS','TOTAL']].sum()
year_sale.head()
# Out:
#          2 W     3 W    4 W   BUS   TOTAL
# YEAR
# 2017    1211   69307   1591    14   72123
# 2018   17062  110375   2500   680  130617
# 2019   30389  133489   1749  1093  166720
# 2020   29112   90361   4323    88  123884
# 2021  156182  147180  14142  1180  318684

# %% [markdown]
# ### EDA

# %%
category
# Out:
#                       State_UTs        Male     Female
# 0               Andhra Pradesh     700840.0    49939.0
# 1            Arunachal Pradesh      24810.0     4481.0
# 2                         Assam    253408.0    18171.0
# 3                         Bihar    884196.0    31427.0
# 4                  Chhattisgarh    642757.0    81252.0
# 5                           Goa     35555.0    17629.0
# 6                       Gujarat    728119.0    99102.0
# 7                      Haryana     282891.0    51525.0
# 8             Himachal Pradesh     191214.0    18197.0
# 9             Jammu and Kashmir     75199.0    18363.0
# 10                    Jharkhand    251438.0    22605.0
# 11                   Karnataka    1446334.0   193981.0
# 12                       Kerala    714139.0   295886.0
# 13               Madhya Pradesh    678039.0     2186.0
# 14                  Maharashtra   1301012.0   244104.0
# 15                      Manipur     31582.0     2661.0
# ...

# %%
sns.barplot(data = category, y ='State_UTs', x ='Male')
plt.show()

# %% [markdown]
# #### From the above graph we can know that male from the Karnataka and Uttar pradesh are the one who bought more.

# %%
sns.barplot(data = category, y ='State_UTs', x ='Female')
plt.show()

# %% [markdown]
# #### From the above graph we can know that female from the Kerala and Tamil Nadu are the one who bought more.

# %%
category = category[:36]

# %%
category.shape
# Out:
# (36, 3)

# %%
charge.head()
# Out:
#             State/UT  EV Charging Facility
# 0     Andhra Pradesh                    65
# 1  Arunachal Pradesh                     4
# 2              Assam                    19
# 3              Bihar                    26
# 4         Chandigarh                     4

# %%
sns.pointplot(data = charge,x = 'EV Charging Facility',y = 'State/UT')
# Out:
# <Axes: xlabel='EV Charging Facility', ylabel='State/UT'>

# %% [markdown]
# #### From the above graph we can know that Madhya pradesh and Rajasthan are the cities that have EV charging Facility most

# %%
car.head()
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla  Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                      ID.3 Pure      10.0           160
# 2    Polestar                              2       4.7           210
# 3         BMW                            iX3       6.8           180
# 4       Honda                              e       9.5           145
#
#    Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161             940         Yes        AWD
# 1       270              167             250          No        RWD
# 2       400              181             620         Yes        AWD
# 3       360              206             560         Yes        RWD
# 4       170              168             190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
sns.catplot(data = car, x = 'Brand', kind ='count',height = 6 ,aspect = 2)
plt.tick_params(axis = 'x', rotation = 45)
plt.show()
# Out:
# C:\Intel\gp\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### From the above graph we can know that Tesla, Audi are the ones who have more into EV.

# %%
x = car['BodyStyle'].value_counts().plot.pie(radius = 2, cmap = 'viridis')
plt.pie(x = [1], radius = 1.2, colors = 'white')
plt.show()

# %% [markdown]
# #### From the above graph we can know that SUV and Hatchback are the bodytypes that are mostly use.

# %%
sns.catplot(data = car, x = 'Segment', kind='count',palette = 'viridis')
plt.show()
# Out:
# C:\Intel\gp\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### From the above graph we can know that Segment C and B are the types that are usaully made in EV.

# %%
# ?sns.catplot

# %%
sns.catplot(data = car, x ='Seats',kind = 'count',palette = "flare")
plt.show()
# Out:
# C:\Intel\gp\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### From the above graph we can know that 5 seater car has more power in market.

# %%
sns.catplot(data = car,x = 'Brand', y= 'Seats',kind = 'bar',height = 7,aspect = 2, palette = "flare")
plt.tick_params(axis = 'x',rotation = 45)
plt.show()
# Out:
# C:\Intel\gp\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### From the above graph we can know that Tesla and Mercedes with 5-6 seater are sold most in the market.

# %%
car.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
sns.catplot(data = car , x = 'PlugType',kind = 'bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 sns.catplot(data = car , x = 'PlugType',kind = 'bar')
#       2 plt.show()
#
# File C:\Intel\gp\Lib\site-packages\seaborn\categorical.py:3187, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3185 p = _CategoricalPlotter()
#    3186 p.require_numeric = plotter_class.require_numeric
# -> 3187 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3188 if (
#    3189     order is not None
#    3190     or (sharex and p.orient == "v")
#    3191     or (sharey and p.orient == "h")
#    3192 ):
# ...

# %%
sns.catplot(data = car,x = 'PlugType',kind = 'count',height = 7,aspect = 2, palette = "flare")
plt.tick_params(axis = 'x',rotation = 45)
plt.show()
# Out:
# C:\Intel\gp\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### From the above graph we can know that Type 2 CCS type is used in mostly in EV.

# %%
car.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
plt.plot(car['PriceEuro'])

# %%
car.head()
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla  Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                      ID.3 Pure      10.0           160
# 2    Polestar                              2       4.7           210
# 3         BMW                            iX3       6.8           180
# 4       Honda                              e       9.5           145
#
#    Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161             940         Yes        AWD
# 1       270              167             250          No        RWD
# 2       400              181             620         Yes        AWD
# 3       360              206             560         Yes        RWD
# 4       170              168             190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
sns.heatmap(car[['AccelSec','TopSpeed_KmH','Range_Km','Efficiency_WhKm','FastCharge_KmH','Seats','PriceEuro']].corr(),annot=True)
plt.show()

# %%
car.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
sns.catplot(data = car,x = 'Brand', y= 'Range_Km',kind = 'bar',height = 7,aspect = 2,palette = "flare")
plt.tick_params(axis = 'x',rotation = 45)
plt.show()
# Out:
# C:\Intel\gp\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### From the above graph we can know that Lucid and Lightyear are the brands which offer the high range in KM.

# %%
regi.head()
# Out:
#   Sl. No.             Category     2022     2023  % Growth
# 0       1           2 Wheelers   631464   859376     36.09
# 1       2           3 Wheelers   352710   582793     65.23
# 2       3  Commercial Vehicles     2649     5673    114.16
# 3       4   Passenger Vehicles    38240    82105    114.71
# 4   Total                Total  1025063  1529947     49.25

# %%
regi = regi[:4]

# %%
regi
# Out:
#   Sl. No.             Category    2022    2023  % Growth
# 0       1           2 Wheelers  631464  859376     36.09
# 1       2           3 Wheelers  352710  582793     65.23
# 2       3  Commercial Vehicles    2649    5673    114.16
# 3       4   Passenger Vehicles   38240   82105    114.71

# %%
sns.catplot(data = regi,x = 'Category',y = '2022',kind = 'bar',height = 7,aspect = 2,palette = 'flare')
plt.tick_params(axis = 'x',rotation = 45)
plt.show()

sns.catplot(data = regi,x = 'Category',y = '2023',kind = 'bar',height = 7,aspect = 2, palette = 'flare')
plt.tick_params(axis = 'x',rotation = 45)
plt.show()
# Out:
# C:\Intel\gp\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Intel\gp\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### From the above graph we can know that in 2022 and 2023, 2 Wheelers EV are sold most.

# %%
year_sale.head()
# Out:
#         YEAR  2 W   3 W  4 W  BUS  TOTAL  year
# 0 2017-04-01   96  4748  198    0   5042  2017
# 1 2017-05-01   91  6720  215    2   7028  2017
# 2 2017-06-01  137  7178  149    1   7465  2017
# 3 2017-07-01  116  8775  120    0   9011  2017
# 4 2017-08-01   99  8905  137    0   9141  2017

# %%
sns.barplot(data = year_sale, x = 'year',y = '2 W',palette = 'flare')
# Out:
# <Axes: xlabel='year', ylabel='2 W'>

# %% [markdown]
# #### From the above graph we can know that how the 2 Wheeler evaluation over the years.

# %%
sns.barplot(data = year_sale, x = 'year',y = '3 W',palette = 'flare')
# Out:
# <Axes: xlabel='year', ylabel='3 W'>

# %% [markdown]
# #### From the above graph we can know that how the 3 Wheeler evaluation over the years.

# %%
sns.barplot(data = year_sale, x = 'year',y = '4 W',palette = 'flare')
# Out:
# <Axes: xlabel='year', ylabel='4 W'>

# %% [markdown]
# #### From the above graph we can know that how the 4 Wheeler evaluation over the years.

# %%
sns.barplot(data = year_sale, x = 'year',y = 'BUS',palette = 'flare')
# Out:
# <Axes: xlabel='year', ylabel='BUS'>

# %% [markdown]
# #### From the above graph we can know that how the bus evaluation over the years.

# %%
X=car[['AccelSec','TopSpeed_KmH','Efficiency_WhKm','FastCharge_KmH', 'Range_Km', 'RapidCharge', 'Seats', 'PriceEuro','PowerTrain']]
X
# Out:
#      AccelSec  TopSpeed_KmH  Efficiency_WhKm  FastCharge_KmH  Range_Km  \
# 0         4.6           233              161             940       450
# 1        10.0           160              167             250       270
# 2         4.7           210              181             620       400
# 3         6.8           180              206             560       360
# 4         9.5           145              168             190       170
# ..        ...           ...              ...             ...       ...
# 98        7.5           160              191             440       330
# 99        4.5           210              258             540       335
# 100       5.9           200              194             440       325
# 101       5.1           200              232             450       375
# 102       7.5           190              238             480       400
#
#     RapidCharge  Seats  PriceEuro PowerTrain
# 0           Yes      5      55480        AWD
# ...
